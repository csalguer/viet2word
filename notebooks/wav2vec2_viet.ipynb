# %%
# !pip3 install torch
# !pip3 install datasets>=1.18.3
# !pip3 install transformers==4.11.3
# !pip3 install librosa
# !pip3 install jiwer
# !pip3 install soundfile pyctcdecode==v0.1.0
# !pip3 install https://github.com/kpu/kenlm/archive/master.zip
# Out:
# Requirement already satisfied: torch in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: filelock in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from torch) (3.12.0)
# Requirement already satisfied: typing-extensions in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from sympy->torch) (1.3.0)
# Collecting transformers==4.11.3
#   Downloading transformers-4.11.3-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 32.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (3.12.0)
# Collecting huggingface-hub>=0.0.17 (from transformers==4.11.3)
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (2023.3.23)
# Requirement already satisfied: requests in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (2.28.2)
# Requirement already satisfied: sacremoses in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (0.0.53)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (0.10.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from transformers==4.11.3) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from huggingface-hub>=0.0.17->transformers==4.11.3) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from requests->transformers==4.11.3) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from requests->transformers==4.11.3) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from requests->transformers==4.11.3) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from requests->transformers==4.11.3) (2022.12.7)
# Requirement already satisfied: six in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from sacremoses->transformers==4.11.3) (1.16.0)
# Requirement already satisfied: click in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from sacremoses->transformers==4.11.3) (8.1.3)
# Requirement already satisfied: joblib in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from sacremoses->transformers==4.11.3) (1.2.0)
# Installing collected packages: huggingface-hub, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.0.12
#     Uninstalling huggingface-hub-0.0.12:
#       Successfully uninstalled huggingface-hub-0.0.12
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.9.2
#     Uninstalling transformers-4.9.2:
#       Successfully uninstalled transformers-4.9.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 1.11.0 requires huggingface-hub<0.1.0, but you have huggingface-hub 0.13.4 which is incompatible.
# Successfully installed huggingface-hub-0.13.4 transformers-4.11.3
# Collecting librosa
#   Downloading librosa-0.10.0.post2-py3-none-any.whl (253 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 7.9 MB/s eta 0:00:00
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.0.tar.gz (377 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 26.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from librosa) (1.24.2)
# Collecting scipy>=1.2.0 (from librosa)
#   Downloading scipy-1.10.1-cp39-cp39-macosx_12_0_arm64.whl (28.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.9/28.9 MB 47.6 MB/s eta 0:00:0000:0100:01
# Collecting scikit-learn>=0.20.0 (from librosa)
#   Downloading scikit_learn-1.2.2-cp39-cp39-macosx_12_0_arm64.whl (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 50.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: joblib>=0.14 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from librosa) (5.1.1)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.56.4-cp39-cp39-macosx_11_0_arm64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 43.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: soundfile>=0.12.1 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from librosa) (0.12.1)
# Collecting pooch<1.7,>=1.0 (from librosa)
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 7.2 MB/s eta 0:00:00
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.3.5-cp39-cp39-macosx_11_0_arm64.whl (381 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 381.3/381.3 kB 36.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from librosa) (4.5.0)
# Collecting lazy-loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.0.5-cp39-cp39-macosx_11_0_arm64.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.5/70.5 kB 9.8 MB/s eta 0:00:00
# Collecting llvmlite<0.40,>=0.39.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.39.1-cp39-cp39-macosx_11_0_arm64.whl (23.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 53.1 MB/s eta 0:00:0000:0100:01
# Collecting numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 (from librosa)
#   Downloading numpy-1.23.5-cp39-cp39-macosx_11_0_arm64.whl (13.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 40.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from numba>=0.51.0->librosa) (67.6.1)
# Collecting appdirs>=1.3.0 (from pooch<1.7,>=1.0->librosa)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from pooch<1.7,>=1.0->librosa) (2.28.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn>=0.20.0->librosa)
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: cffi>=1.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from requests>=2.19.0->pooch<1.7,>=1.0->librosa) (2022.12.7)
# Building wheels for collected packages: audioread
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-3.0.0-py3-none-any.whl size=23706 sha256=949a2e61a969cd20af1696332317a9cea50bfa89e0e5fa9fd0a1842dda0ce826
#   Stored in directory: /Users/thaumaturge/Library/Caches/pip/wheels/e4/76/a4/cfb55573167a1f5bde7d7a348e95e509c64b2c3e8f921932c3
# Successfully built audioread
# Installing collected packages: msgpack, appdirs, threadpoolctl, numpy, llvmlite, lazy-loader, audioread, soxr, scipy, pooch, numba, scikit-learn, librosa
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.2
#     Uninstalling numpy-1.24.2:
#       Successfully uninstalled numpy-1.24.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 1.11.0 requires huggingface-hub<0.1.0, but you have huggingface-hub 0.13.4 which is incompatible.
# Successfully installed appdirs-1.4.4 audioread-3.0.0 lazy-loader-0.2 librosa-0.10.0.post2 llvmlite-0.39.1 msgpack-1.0.5 numba-0.56.4 numpy-1.23.5 pooch-1.6.0 scikit-learn-1.2.2 scipy-1.10.1 soxr-0.3.5 threadpoolctl-3.1.0
# Collecting jiwer
#   Downloading jiwer-3.0.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from jiwer) (8.1.3)
# Collecting rapidfuzz==2.13.7 (from jiwer)
#   Downloading rapidfuzz-2.13.7-cp39-cp39-macosx_11_0_arm64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 21.2 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: rapidfuzz, jiwer
# Successfully installed jiwer-3.0.1 rapidfuzz-2.13.7
# Requirement already satisfied: soundfile in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: pyctcdecode==v0.1.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (0.1.0)
# Requirement already satisfied: numpy<2.0.0,>=0.16.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from pyctcdecode==v0.1.0) (1.23.5)
# Requirement already satisfied: pygtrie<3.0,>=2.1 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from pyctcdecode==v0.1.0) (2.5.0)
# Requirement already satisfied: cffi>=1.0 in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /Users/thaumaturge/.virtualenvs/viet2word/lib/python3.9/site-packages (from cffi>=1.0->soundfile) (2.21)
# Collecting https://github.com/kpu/kenlm/archive/master.zip
#   Using cached https://github.com/kpu/kenlm/archive/master.zip
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
from transformers.file_utils import cached_path, hf_bucket_url
import os, zipfile
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
from datasets import load_dataset
import soundfile as sf
import torch
import kenlm
from pyctcdecode import Alphabet, BeamSearchDecoderCTC, LanguageModel
import IPython

# %%
cache_dir = '../.cache/'
processor = Wav2Vec2Processor.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h", cache_dir=cache_dir)
model = Wav2Vec2ForCTC.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h", cache_dir=cache_dir)
lm_file = hf_bucket_url("nguyenvulebinh/wav2vec2-base-vietnamese-250h", filename='vi_lm_4grams.bin.zip')
lm_file = cached_path(lm_file,cache_dir=cache_dir)
with zipfile.ZipFile(lm_file, 'r') as zip_ref:
    zip_ref.extractall(cache_dir)
lm_file = cache_dir + 'vi_lm_4grams.bin'
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 cache_dir = '../.cache/'
#       2 processor = Wav2Vec2Processor.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h", cache_dir=cache_dir)
# ----> 3 model = Wav2Vec2ForCTC.from_pretrained("nguyenvulebinh/wav2vec2-base-vietnamese-250h", cache_dir=cache_dir)
#       4 lm_file = hf_bucket_url("nguyenvulebinh/wav2vec2-base-vietnamese-250h", filename='vi_lm_4grams.bin.zip')
#       5 lm_file = cached_path(lm_file,cache_dir=cache_dir)
#
# AttributeError: type object 'Wav2Vec2ForCTC' has no attribute 'from_pretrained'
